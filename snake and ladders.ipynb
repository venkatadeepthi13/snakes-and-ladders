# %%
import random
token1=1
token2=1
token3=1
token4=1
ladders={4:56,14:55,12:50,22:58,41:78,54:88}
snakes={37:3,47:16,25:10,75:32,94:71,96:42}
while token2<=100 and token4<=100:
    if token1==1:
        p1=random.randint(1,6)
        print('p1 rolled the dice: ',p1)
        if p1==6 and token1==1:
            print('player1 can start the game')
            token1=token1+1
            print(token1)
        else:
            print('player1 can not start the game')
    print("\n")
    if token3==1:
        p2=random.randint(1,6)
        print('p2 can roll the dice: ',p2)
        if p2==6 and token3==1:
            print('player2 can start the game')
            token3=token3+1
        else:
            print('player2 can not start the game')
    if token1>1:
        if token2>100:
            token2=token2-p1
        elif token2==100:
            print('congrations p1 won the game')
            break    
        else:
            p1=random.randint(1,6)
            print('p1 rolled the dice',p1)
            while p1==6:
                token2=token2+p1
                if token2>100:
                    token2=token2-p1
                    print('p1 at the position',token2)
                elif token2==100:
                    print('congrats p1 won the game')
                    break
                else:
                    print('p1 at the position',token2)
                    print('p1 got another chance')
                    p1=random.randint(1,6)
                    print('p1 rolled the dice',p1)
            if token2>100:
                token2=token2-p1
            elif token2==100:
                print('congrations p1 won the game')
                break
            else:
                if p1!=6:
                    token2=token2+p1
                    if token2>100:
                        token2=token2-p1
                        print("p1 is at position",token2)
                    elif token2==100:
                        print("Congratulations p1 won the game")
                        break
            print('p1 is at position',token2)
            if token2 in ladders:
                print('hurray! there is a ladder at',token2)
                token2=ladders[token2]
                print('p1 at the position',token2)
            if token2 in snakes:
                print('oops! there is a snake at',token2)
                token2=snakes[token2]
                print('p1 at the position',token2)
        print("\n")
        if token3>1:
            if token4>100:
                token4=token4-p2
            elif token4==100:
                print('congrations p2 won the game')
                break    
            else:
                p2=random.randint(1,6)
                print('p2 rolled the dice',p2)
                while p2==6:
                    token4=token4+p2
                    if token4>100:
                        token4=token4-p1
                        print('p2 at the position',token4)
                    elif token4==100:
                        print('congrations p2 won the game')
                        break  
                    else:
                        print('p2 at the position',token4)
                        print('p2 got another chance')
                        p2=random.randint(1,6)
                        print('hh',p2)
                        print('p2 rolled the dice',p2)
                if token4>100:
                    token4=token4-p2
                elif token4==100:
                    print('congrations p2 won the game')
                    break
                else:
                    if p2!=6:
                        token4=token4+p2
                        if token4>100:
                            token4=token4-p2
                            print("p2 at the position",token4)
                        elif token4==100:
                            print("Congratulations p2 won the game")
                            break
                print('p2 is at position',token4)
                if token4 in ladders:
                    print('hurray! there is a ladder at',token4)
                    token4=ladders[token4]
                    print('p2 at the position',token4)
                if token4 in snakes:
                    print('oops! there is a snake at',token4)
                    token4=snakes[token4]
                    print('p2 at the position',token4)
    if token2==100:
        print("Congrats Player1 win the game")
        break
    if token4==100:
        print("Congrats player2 win the game")
        break
# Out:
# p1 rolled the dice:  5
# player1 can not start the game
#
#
# p2 can roll the dice:  3
# player2 can not start the game
# p1 rolled the dice:  4
# player1 can not start the game
#
#
# p2 can roll the dice:  1
# player2 can not start the game
# p1 rolled the dice:  1
# player1 can not start the game
#
#
# p2 can roll the dice:  4
# player2 can not start the game
# p1 rolled the dice:  5
# player1 can not start the game
#
#
# p2 can roll the dice:  2
# player2 can not start the game
# p1 rolled the dice:  6
# player1 can start the game
# 2
#
#
# p2 can roll the dice:  6
# player2 can start the game
# p1 rolled the dice 6
# p1 at the position 7
# p1 got another chance
# p1 rolled the dice 3
# p1 is at position 10
#
#
# p2 rolled the dice 6
# p2 at the position 7
# p2 got another chance
# hh 4
# p2 rolled the dice 4
# p2 is at position 11
#
#
# p1 rolled the dice 1
# p1 is at position 11
#
#
# p2 rolled the dice 6
# p2 at the position 17
# p2 got another chance
# hh 3
# ...
